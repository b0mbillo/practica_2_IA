# %% [markdown]
# # Arbol de desicion

# %%
import pickle
datasets = {}

for i in range(1, 9):
    with open(f'pickle/dataset_v{i}.pkl', 'rb') as f:
        datasets[f'v{i}'] = pickle.load(f)

v1 = datasets['v1']
v2 = datasets['v2']
v3 = datasets['v3']
v4 = datasets['v4']
v5 = datasets['v5']
v6 = datasets['v6']
v7 = datasets['v7']
v8 = datasets['v8']

# %%
v1['X_train']
# Out:
#        Age  PlayTimeHours  InGamePurchases  SessionsPerWeek  \
# 659     44       0.760380                0               17
# 14334   42      21.734846                0               11
# 12887   31      14.708138                0                5
# 2636    44      13.831387                0                2
# 12351   21       0.048591                0               17
# ...    ...            ...              ...              ...
# 17740   23      20.572994                1               13
# 6595    37      20.348851                0               12
# 11876   31       7.868160                0               16
# 904     34      16.578312                0               13
# 16634   21       2.877861                0               11
#
#        AvgSessionDurationMinutes  PlayerLevel  AchievementsUnlocked  \
# 659                           94           62                    49
# 14334                        118           10                     4
# ...
